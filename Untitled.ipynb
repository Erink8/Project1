# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
track_data = pd.read_csv("tracks_features.csv")

# %%
track_data
# Out:
#                              id                   name  \
# 0        7lmeHLHBe4nmXzuXc0HDjk                Testify
# 1        1wsRitfRRtWyEapl0q22o8        Guerrilla Radio
# 2        1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb
# 3        2lbASgTSoDO7MTuLAXlTW0              Mic Check
# 4        1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire
# ...                         ...                    ...
# 1204020  0EsMifwUmMfJZxzoMPXJKZ         Gospel of Juke
# 1204021  2WSc2TB1CSJgGE0PEzVeiu          Prism Visions
# 1204022  6iProIgUe3ETpO6UT0v5Hg              Tokyo 360
# 1204023  37B4SXC8uoBsUyKCWnhPfX                 Yummy!
# 1204024  3GgQmOxxLyRoAb4j86zOBX   That's The Way It Is
#
#                              album                album_id  \
# 0        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 1        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 2        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 3        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# ...

# %%
#drop columns we don't need
refined_track_data_columns = track_data[["name", "album", "artists", "danceability", 
                                         "speechiness", "acousticness", "instrumentalness", 
                                         "liveness", "valence","energy", "tempo", "duration_ms", "year"]]
refined_track_data_columns.head()
# Out:
#                     name                      album  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         artists  danceability  speechiness  acousticness  \
# 0  ['Rage Against The Machine']         0.470       0.0727       0.02610
# 1  ['Rage Against The Machine']         0.599       0.1880       0.01290
# 2  ['Rage Against The Machine']         0.315       0.4830       0.02340
# 3  ['Rage Against The Machine']         0.440       0.2370       0.16300
# 4  ['Rage Against The Machine']         0.426       0.0701       0.00162
#
#    instrumentalness  liveness  valence  energy    tempo  duration_ms  year
# 0          0.000011    0.3560    0.503   0.978  117.906       210133  1999
# ...

# %%
renamed_track_data_columns= refined_track_data_columns.rename(columns={"name":"Song Title", "album":"Album Title",
                                          "artists":"Artists", "danceability":"Danceability", "acousticness":"Acousticness",
                                          "speechiness":"Speechiness", "instrumentalness":"Instrumentalness",
                                          "liveness":"Liveness", "valence":"Valence", "energy":"Energy", "tempo":"Tempo", "duration_ms":"Duration(ms)",
                                          "year":"Release Year"})
renamed_track_data_columns.head()
# Out:
#               Song Title                Album Title  \
# 0                Testify  The Battle Of Los Angeles
# 1        Guerrilla Radio  The Battle Of Los Angeles
# 2       Calm Like a Bomb  The Battle Of Los Angeles
# 3              Mic Check  The Battle Of Los Angeles
# 4  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                         Artists  Danceability  Speechiness  Acousticness  \
# 0  ['Rage Against The Machine']         0.470       0.0727       0.02610
# 1  ['Rage Against The Machine']         0.599       0.1880       0.01290
# 2  ['Rage Against The Machine']         0.315       0.4830       0.02340
# 3  ['Rage Against The Machine']         0.440       0.2370       0.16300
# 4  ['Rage Against The Machine']         0.426       0.0701       0.00162
#
#    Instrumentalness  Liveness  Valence  Energy    Tempo  Duration(ms)  \
# 0          0.000011    0.3560    0.503   0.978  117.906        210133
# ...

# %%
sampled_data = renamed_track_data_columns.sample(frac=.01)

# %%
release_year_group = sampled_data.groupby(["Release Year"])
release_year_group.head()
# Out:
#                                                 Song Title  \
# 248707                              Two Can Play That Game
# 989718                                                Hope
# 632981                                                Made
# 965029                          Lights Off - piano version
# 762359                   You Cannot Win If You Do Not Play
# ...                                                    ...
# 1140183         Symphony No. 1 "Jeremiah": II. Profanation
# 449291                                           Ave Maria
# 1119107       Fancy Free Ballet: IV. Pas de deux - Excerpt
# 50672    I Can't Give You Anything but Love (with Teddy...
# 1054977                                         I Love You
#
#                                                Album Title  \
# 248707                                      Dangerous Road
# 989718                          Voez (Original Soundtrack)
# 632981                               Dancing With the Past
# ...

# %%
x_axis = np.arange(len(release_year_group))
tick_locations = [value for value in x_axis]

# %%
release_year_group["Danceability"].mean()
# Out:
# Release Year
# 1908    0.749000
# 1909    0.624000
# 1917    0.436000
# 1926    0.631000
# 1928    0.553000
#           ...
# 2016    0.505128
# 2017    0.493736
# 2018    0.514527
# 2019    0.537801
# 2020    0.555572
# Name: Danceability, Length: 80, dtype: float64

# %%
plt.figure(figsize=(20,4))
plt.bar(x_axis, release_year_group["Danceability"].mean(), color="blue", alpha=0.5, align="center")
plt.xticks(tick_locations, release_year_group["Release Year"].max(), rotation="vertical")
plt.title("Danceability Over Time")
#plt.xticks(tick_locations, rotation="vertical")
# Out:
# Text(0.5, 1.0, 'Danceability Over Time')

# %%
plt.xlim(-.75, len(x_axis))
plt.ylim(0,max(sampled_data["Danceability"])+10)
# Out:
# (0, 10.978)

# %%
plt.tight_layout()
plt.show()
